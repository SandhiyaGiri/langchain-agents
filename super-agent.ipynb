# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "
"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
# Out:
# /Users/sandhiya.cv/Downloads/multi-agent-architecture/sandy_env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# /Users/sandhiya.cv/Downloads/multi-agent-architecture/sandy_env/lib/python3.9/site-packages/google/api_core/_python_version_support.py:252: FutureWarning: You are using a Python version (3.9.6) past its end of life. Google will update google.api_core with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)

# %%
response = model.invoke("Why do parrots talk?")

# %%
print(response)
# Out:
# content='Parrots talk primarily for **social reasons and communication**, stemming from their highly intelligent and social nature. They are not just mimicking sounds like a recording device; they are learning and using vocalizations to interact with their environment and their flock (which, in captivity, includes their human family).\n\nHere\'s a breakdown of the key reasons why parrots talk:\n\n**1. Social Bonding and Flock Communication:**\n\n* **Wild Parrots:** In their natural habitats, parrots live in large, complex social groups. Vocalizations are crucial for maintaining these bonds, coordinating activities, and signaling danger or the presence of food. They use a wide range of calls, squawks, and whistles to communicate with each other.\n* **Captive Parrots:** When kept as pets, parrots imprint on their human "flock." They see humans as their social group and their primary source of interaction. Talking becomes their way of participating in this social dynamic, mirroring the communication they would engage in with other parrots.\n\n**2. Mimicry and Learning:**\n\n* **Exceptional Mimics:** Parrots have highly developed vocal tracts and brains that allow them to precisely replicate sounds they hear. This ability is not unique to parrots (some other birds and even mammals can mimic), but parrots are among the most adept.\n* **Learning by Imitation:** They learn by observing and imitating the sounds made by their social group. This includes other parrots, and in a domestic setting, it includes human speech, laughter, and other noises.\n\n**3. Seeking Attention and Interaction:**\n\n* **"Hey, I\'m Here!":** Talking is a very effective way for a parrot to get noticed. If they see their human looking away or are feeling a bit bored, a well-timed word or phrase can immediately draw attention.\n* **Requesting Things:** Over time, parrots learn to associate certain words or phrases with specific actions or outcomes. They might say "hello" when they want attention, "treat" when they want food, or "bye-bye" when they want to be left alone.\n\n**4. Expressing Emotions and Needs:**\n\n* **Happiness and Excitement:** A parrot might repeat happy phrases or sounds when they are content or excited.\n* **Frustration or Discomfort:** While less common, some parrots may use vocalizations to express frustration or discomfort, though these are often more guttural or agitated sounds.\n* **Mimicking a Stimulus:** Sometimes, a parrot might mimic a sound simply because it\'s an interesting or recurring sound in their environment. For example, if the doorbell rings frequently, they might learn to mimic it.\n\n**5. Cognitive Stimulation and Intelligence:**\n\n* **Mental Exercise:** Learning and using vocalizations is a form of mental stimulation for these intelligent creatures. It keeps their minds active and engaged.\n* **Problem-Solving:** Some studies suggest that parrots can learn to use words in context, demonstrating a degree of understanding beyond simple mimicry. They might learn to associate a word with an object or an action.\n\n**It\'s important to understand what "talking" means for a parrot:**\n\n* **Not True Language:** While parrots can learn many words and phrases and even use them in seemingly appropriate contexts, they don\'t possess the grammatical structure or abstract reasoning that defines human language.\n* **Association and Context:** Their "understanding" is primarily based on associating sounds with specific situations, rewards, or social cues.\n\nIn summary, parrots talk because it\'s an inherent part of their social structure, their learning process, and their way of interacting with their environment and their human flock. They are intelligent, social animals who have evolved to be excellent communicators, and in our homes, they extend this ability to us.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', ...

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# <bound method BaseMessage.text of AIMessageChunk(content='Parrots have', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_tokens': 8, 'output_tokens': 3, 'total_tokens': 11, 'input_token_details': {'cache_read': 0}})>|<bound method BaseMessage.text of AIMessageChunk(content=' colorful feathers for a variety of fascinating and interconnected reasons, primarily revolving around **survival and reproduction**.', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_token_details': {'cache_read': 0}, 'input_tokens': 0, 'total_tokens': 19, 'output_tokens': 19})>|<bound method BaseMessage.text of AIMessageChunk(content=' Here\'s a breakdown of the key drivers:\n\n**1. Communication and Social Signaling:**\n\n* **Species Recognition:** The specific patterns and colors of a parrot\'s plumage act like a unique "uniform" for their species. This helps them quickly', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_token_details': {'cache_read': 0}, 'input_tokens': 0, 'total_tokens': 51, 'output_tokens': 51})>|<bound method BaseMessage.text of AIMessageChunk(content=' identify and distinguish individuals of their own kind from other birds, which is crucial for forming flocks, finding mates, and avoiding interbreeding.\n* **Individual Recognition:** Within a species, subtle variations in color and feather patterns can help parrots recognize individuals', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_token_details': {'cache_read': 0}, 'input_tokens': 0, 'total_tokens': 49, 'output_tokens': 49})>|<bound method BaseMessage.text of AIMessageChunk(content=", such as their mate, offspring, or members of their social group.\n* **Mood and Status Display:** While not as dramatic as some other animals, changes in feather erection or subtle shifts in color can sometimes indicate a parrot's emotional", additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_token_details': {'cache_read': 0}, 'input_tokens': 0, 'total_tokens': 49, 'output_tokens': 49})>|<bound method BaseMessage.text of AIMessageChunk(content=' state (e.g., excitement, aggression, fear).\n* **Mating Displays:** Bright, vibrant colors are often a sign of good health and genetic quality. During courtship, males may display their most colorful plumage to attract females.', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_token_details': {'cache_read': 0}, 'input_tokens': 0, 'total_tokens': 48, 'output_tokens': 48})>|<bound method BaseMessage.text of AIMessageChunk(content=' A female parrot might choose a mate based on the brilliance and integrity of his feathers.\n\n**2. Camouflage and Predator Avoidance:**\n\n* **Blending into the Environment:** While many people associate parrots with bright, conspicuous colors, it', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_token_details': {'cache_read': 0}, 'input_tokens': 0, 'total_tokens': 48, 'output_tokens': 48})>|<bound method BaseMessage.text of AIMessageChunk(content="'s important to remember that their natural habitats are often lush and vibrant. Greens, blues, and yellows can help them blend seamlessly into foliage, making it harder for predators to spot them.\n* **Disruptive Coloration:** Bold", additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--1cc27fcc-83de-47a2-884e-f25302f0d24b', usage_metadata={'input_token_details': {'cache_read': 0}, 'input_tokens': 0, 'total_tokens': 48, 'output_tokens': 48})>|<bound method BaseMessage.text  ...

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for a variety of reasons, and it's a fascinating interplay of **evolutionary pressures** and **biological functions**. Here are the main drivers behind their vibrant plumage:\n\n**1. Communication and Social Signaling:**\n\n* **Species Recognition:** Different species of parrots have distinct color patterns. This helps them recognize their own kind, which is crucial for finding mates, forming flocks, and avoiding interbreeding. Imagine trying to find your family in a crowded forest if everyone looked the same!\n* **Individual Recognition:** Within a species, subtle variations in feather color can help individuals recognize each other. This is important for pair bonding, recognizing offspring, and maintaining social hierarchies.\n* **Mating Displays:** The most striking colors are often used in courtship rituals. Males may display their brightest feathers to impress females, signaling their health, vigor, and genetic quality. A vibrant display can be a strong indicator of a healthy and desirable mate.\n* **Mood and Status:** While less understood, some research suggests that feather color might also change slightly with a parrot's mood or social status. For example, brighter colors could indicate dominance or excitement.\n\n**2. Camouflage:**\n\n* **Blending in with the Environment:** While many parrots are vividly colored, their colors often mimic the fruits, flowers, and foliage of their native habitats. This allows them to blend in with their surroundings, making them harder for predators to spot. Think of a green parrot in a leafy tree, or a red parrot near bright berries.\n* **Predator Evasion:** By being able to hide effectively, parrots increase their chances of survival. This is especially important for younger or less experienced birds.\n\n**3. Thermoregulation (Less Significant, but a Factor):**\n\n* **Heat Absorption/Reflection:** While not the primary reason, the colors of feathers can play a small role in absorbing or reflecting sunlight, helping parrots regulate their body temperature in different climates. Darker colors absorb more heat, while lighter colors reflect it.\n\n**4. Attraction (Beyond Mating):**\n\n* **Flock Cohesion:** Bright colors can help parrots keep track of each other in flight and when foraging in large flocks. This visual cue helps maintain group unity and safety.\n\n**How do they get these colors?**\n\nThe vibrant colors of parrot feathers are a result of two main types of pigments:\n\n* **Melanins:** These pigments produce blacks, browns, and some muted reds and yellows. They are produced by the parrot's own body.\n* **Carotenoids:** These pigments produce bright reds, oranges, and yellows. Parrots cannot produce carotenoids themselves; they must obtain them from their diet, primarily from fruits and vegetables. This is why a parrot's diet is crucial for maintaining its vibrant colors.\n\n**In summary, the colorful feathers of parrots are a sophisticated evolutionary adaptation that serves multiple vital functions, from finding a mate and recognizing family to evading predators and staying connected with their flock.** It's a beautiful testament to the power of natural selection shaping life on Earth." additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': []} id='run--79a51856-b03b-474f-9586-72cce9df1828-0' usage_metadata={'input_tokens': 8, 'output_tokens': 629, 'total_tokens': 637, 'input_token_details': {'cache_read': 0}}
# content='Airplanes fly through a fascinating interplay of physics, primarily driven by the concept of **lift**. Here\'s a breakdown of how it works:\n\n**The Four Forces of Flight:**\n\nTo understand how an airplane flies, we need to consider the four fundamental forces acting on it:\n\n1.  **Lift:** The upward force that opposes weight and keeps the airplane in the air.\n2.  **Weight:** The downward force due to gravity acting on the airplane\'s mass.\n3.  **Thrust:** The forward force generated by the engines, propelling the airplane through the air.\n4.  **Drag:** The backward force that opposes thrust, caused by air resistance.\n\nFor an airplane to fly, **lift must be greater than or equal to weight**, and **thrust must be greater than or equal to drag**.\n\n**How Lift is Generated: The Role of the Wings (Airfoils)**\n\nThe magic of lift primarily happens at the wings. Airplane wings are not flat; they have a specific shape called an **airfoil**. The key features of an airfoil are:\n\n*   **Curved Upper Surface:** The top surface of the wing is typically more curved than the bottom surface.\n*   **Flatter Lower Surface:** The bottom surface is relatively flatter.\n\nThis shape is crucial because of **Bernoulli\'s Principle** and **Newton\'s Third Law of Motion**.\n\n*   **Bernoulli\'s Principle (The "Faster Air, Lower Pressure" Idea):**\n    *   As the airplane moves forward (thanks to thrust), air flows over and under the wings.\n    *   Because the upper surface is curved, the air traveling over the top has to travel a slightly longer distance than the air traveling under the bottom in the same amount of time.\n    *   To cover this longer distance in the same time, the air on top must move **faster**.\n    *   According to Bernoulli\'s Principle, **faster-moving air exerts lower pressure**.\n    *   Therefore, the pressure above the wing is **lower** than the pressure below the wing.\n    *   This **pressure difference** creates an upward force, which is lift.\n\n*   **Newton\'s Third Law of Motion (The "Action-Reaction" Idea):**\n    *   The curved shape of the wing also forces the air flowing over it to be deflected **downwards**.\n    *   Newton\'s Third Law states that for every action, there is an equal and opposite reaction.\n    *   The action is the wing pushing air downwards.\n    *   The reaction is the air pushing the wing **upwards**, contributing to lift.\n\n**The Angle of Attack:**\n\nThe **angle of attack** is the angle between the wing\'s chord line (an imaginary line from the leading edge to the trailing edge) and the oncoming air.\n\n*   Increasing the angle of attack generally increases lift.\n*   However, if the angle of attack becomes too steep, the airflow over the top of the wing can separate, causing a **stall**, where lift is drastically reduced.\n\n**The Role of Thrust:**\n\n*   **Engines** (jet engines or propellers) provide the **thrust** needed to move the airplane forward.\n*   This forward motion is essential for air to flow over the wings and generate lift.\n*   Without sufficient thrust, the airplane wouldn\'t gain the speed necessary to produce enough lift to overcome its weight.\n\n**How Airplanes Take Off, Cruise, and Land:**\n\n*   **Takeoff:** Engines provide maximum thrust, accelerating the airplane down the runway. As speed increases, lift also increases. When lift equals or exceeds weight, the airplane becomes airborne.\n*   **Cruising:** The pilot adjusts engine power to maintain a balance between thrust and drag, and the wings are angled to generate enough lift to counteract weight.\n*   **Landing:** The pilot reduces thrust, and often uses flaps and slats (movable sections of the wings) to increase drag and lift at lower speeds. The airplane descends by gradually reducing lift and increasing drag.\n\n**In Summary:**\n\nAirplanes fly because their wings are designed with an airfoil shape that creates a difference in air pressure above and below the wing. This pressure differen ...
# content="Quantum computing is a revolutionary new type of computing that leverages the principles of quantum mechanics to perform calculations. Unlike classical computers that use bits to represent information as either 0 or 1, quantum computers use **qubits**.\n\nHere's a breakdown of what makes quantum computing so special:\n\n**The Core Concepts:**\n\n*   **Qubits (Quantum Bits):** This is the fundamental unit of information in quantum computing. Unlike classical bits, which are definitively 0 or 1, a qubit can exist in a **superposition** of both 0 and 1 simultaneously. Think of it like a spinning coin before it lands – it's neither heads nor tails, but a combination of both. This allows quantum computers to explore many possibilities at once.\n\n*   **Superposition:** As mentioned above, this is the ability of a qubit to be in multiple states at the same time. The more qubits you have, the exponentially larger the number of possible states the quantum computer can represent and explore. For example, with 2 qubits, you can represent 4 states simultaneously (00, 01, 10, 11), whereas a classical computer would need 2 bits to represent one of those states at a time. With 300 qubits, a quantum computer could represent more states than there are atoms in the observable universe!\n\n*   **Entanglement:** This is another bizarre but powerful quantum phenomenon. When qubits are entangled, they become interconnected in such a way that their fates are linked, regardless of the distance separating them. Measuring the state of one entangled qubit instantly influences the state of the other. This allows for complex correlations and computations that are impossible with classical systems.\n\n*   **Quantum Tunneling:** While not as central as superposition and entanglement, quantum tunneling is a phenomenon where a quantum particle can pass through a potential energy barrier that it would classically not have enough energy to overcome. This can be relevant in certain quantum algorithms and hardware designs.\n\n**How is it Different from Classical Computing?**\n\n| Feature           | Classical Computing                                | Quantum Computing                                                                   |\n| :---------------- | :------------------------------------------------- | :---------------------------------------------------------------------------------- |\n| **Basic Unit**    | Bit (0 or 1)                                       | Qubit (0, 1, or a superposition of both)                                            |\n| **Information Representation** | Deterministic states                              | Probabilistic states, superposition of states                                       |\n| **Computation**   | Sequential processing of bits                      | Parallel exploration of multiple possibilities due to superposition and entanglement |\n| **Algorithms**    | Designed for deterministic operations              | Designed to exploit quantum phenomena for specific problems                         |\n| **Problem Solving** | Excellent for tasks with clear, sequential steps   | Potentially revolutionary for certain complex problems that are intractable for classical computers |\n\n**What Problems Can Quantum Computers Solve?**\n\nQuantum computers are not meant to replace classical computers for everyday tasks like browsing the web or word processing. Instead, they are designed to tackle specific types of problems that are currently impossible or take an impractically long time to solve on even the most powerful supercomputers. These include:\n\n*   **Drug Discovery and Materials Science:** Simulating the behavior of molecules and materials at the quantum level to design new drugs, catalysts, and advanced materials with unprecedented properties.\n*   **Optimization Problems:** Finding the best solutions to complex problems with many variables, such as logistics, financial modeling, and supply chain management.\n ...
